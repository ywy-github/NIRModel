# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data=pd.read_excel("../data/CVd-2914例(训练2204+测试710)-新增54例测试集-测试有标签-20230831.xlsx")
data
# Out:
#       是否为上海肿瘤数据类型        ids                                       dcm_name  \
# 0               0   4_2577_左  020-ZSSYX-01921-LRLI-202302151434-双波段-L-D.bmp
# 1               0    4_235_右   020-ZSSYX-0150-LYFA-202203021012-单波段-R-D.bmp
# 2               0    4_702_左  020-ZSSYX-00423-ZGXI-202204131040-双波段-L-D.bmp
# 3               0   4_2320_右  020-ZSSYX-01772-TAMI-202210201555-双波段-R-D.bmp
# 4               0    4_807_右  020-ZSSYX-00504-LYFE-202204241000-双波段-R-D.bmp
# ...           ...        ...                                            ...
# 2199            1   一期_293_左      0571-ZHJSH-00019-HPX-201807090942-D-L.bmp
# 2200            1   一期_590_右          021-SHZL-00339-ZHH-201809191443-D.bmp
# 2201            1   一期_140_左           021-SHZL-00139-XJ-201803201126-D.bmp
# 2202            0  一期_1472_右        022-TJZL-00106-ZHWZH-201811021518-D.bmp
# 2203            0   一期_690_右           028-CDFE-00009-HJ-201812260942-D.bmp
#
#       tumor_nature                                          对侧dcm  age  \
# 0                1  020-ZSSYX-01921-LRLI-202302151438-双波段-R-D.dcm   69
# 1                0   020-ZSSYX-0150-LYFA-202203021008-单波段-L-D.dcm   63
# 2                0  020-ZSSYX-00423-ZGXI-202204131053-双波段-R-D.dcm   50
# 3                0  020-ZSSYX-01772-TAMI-202210201559-双波段-L-D.dcm   31
# 4                0  020-ZSSYX-00504-LYFE-202204240954-双波段-L-D.dcm   34
# ...            ...                                            ...  ...
# 2199             0      0571-ZHJSH-00019-HPX-201807090946-D-R.dcm   29
# 2200             0                                            NaN   47
# 2201             1                                            NaN   38
# 2202             1                                            NaN   44
# 2203             0           028-CDFE-00009-HJ-201812260942-D.dcm   56
#
#      cup_size new_qc                                             病灶位置  \
# 0           B     合格                               ['[nan]', '[nan]']
# 1           C     合格                               ['[nan]', '[nan]']
# 2           C     合格                      ['[nan]', '[nan]', '[nan]']
# 3           D     合格                               ['[nan]', '[nan]']
# 4           C     合格                               ['[nan]', '[nan]']
# ...       ...    ...                                              ...
# 2199        C     合格                                            1点/2点
# 2200        B     合格                                    NULL右乳下方右乳上象限
# 2201        B     合格                                           左内侧左内下
# 2202        C     合格                                       内上内侧距乳头2cm
# 2203        D     合格  9点距乳头2-3cm9点距乳头约2-3cm/9-10点距乳头2cm/10点距乳头3cmNULL
#
#          是否乳头区  ...                us_size us_bi_rads mg_location mg_size  \
# 0           未知  ...     ['19.0*15.0*12.0']     ['4C']         NaN     NaN
# 1           未知  ...           ['15.0*6.0']     ['4A']         NaN     NaN
# 2           未知  ...           ['13.0*5.0']     ['4A']       [nan]   [nan]
# 3           未知  ...     ['42.0*24.0*42.0']     ['4A']         NaN     NaN
# 4           未知  ...          ['19.0*10.0']     ['4A']         NaN     NaN
# ...        ...  ...                    ...        ...         ...     ...
# 2199      非乳头区  ...  ['6.9*5.5/18.3*10.8']      ['3']         NaN     NaN
# 2200      非乳头区  ...           ['17*11*15']     ['4A']   ['右乳上象限']   [nan]
# 2201      非乳头区  ...            ['10*14*9']     ['4C']     ['左内下']   [nan]
# 2202       乳头区  ...              ['37*20']     ['4B']         NaN     NaN
# 2203  乳头区，非乳头区  ...      ['6*5*6/5*2/4*3']     ['4A']       [nan]   [nan]
#
#       mg_bi_rads  mri_location mri_size mri_bi_rads is_normal_dcm  \
# 0            NaN           NaN      NaN         NaN             0
# 1            NaN           NaN      NaN         NaN             1
# 2          ['2']           NaN      NaN         NaN             1
# 3            NaN           NaN      NaN         NaN             0
# 4            NaN           NaN      NaN         NaN             1
# ...          ...           ...      ...         ...           ...
# 2199         NaN           NaN      NaN         NaN             1
# 2200       ['3']           NaN      NaN         NaN             1
# 2201       ['0']           NaN      NaN         NaN             1
# 2202         NaN           NaN      NaN         NaN             1
# 2203       [nan]           NaN      NaN         NaN             1
#
#                        dcm_type
# 0     LittleLED=2;TwoLEDMode=0;
# 1                           NaN
# 2                           NaN
# 3     LittleLED=2;TwoLEDMode=0;
# 4                           NaN
# ...                         ...
# 2199                        NaN
# 2200                        NaN
# 2201                        NaN
# 2202                        NaN
# 2203                        NaN
#
# [2204 rows x 34 columns]

# %%
y=data.loc[:,"tumor_nature"]
X=data.drop(["tumor_nature"],axis=1)
y,X
# Out:
# (0       1
#  1       0
#  2       0
#  3       0
#  4       0
#         ..
#  2199    0
#  2200    0
#  2201    1
#  2202    1
#  2203    0
#  Name: tumor_nature, Length: 2204, dtype: int64,
#        是否为上海肿瘤数据类型        ids                                       dcm_name  \
#  0               0   4_2577_左  020-ZSSYX-01921-LRLI-202302151434-双波段-L-D.bmp
#  1               0    4_235_右   020-ZSSYX-0150-LYFA-202203021012-单波段-R-D.bmp
#  2               0    4_702_左  020-ZSSYX-00423-ZGXI-202204131040-双波段-L-D.bmp
#  3               0   4_2320_右  020-ZSSYX-01772-TAMI-202210201555-双波段-R-D.bmp
#  4               0    4_807_右  020-ZSSYX-00504-LYFE-202204241000-双波段-R-D.bmp
#  ...           ...        ...                                            ...
#  2199            1   一期_293_左      0571-ZHJSH-00019-HPX-201807090942-D-L.bmp
#  2200            1   一期_590_右          021-SHZL-00339-ZHH-201809191443-D.bmp
#  2201            1   一期_140_左           021-SHZL-00139-XJ-201803201126-D.bmp
#  2202            0  一期_1472_右        022-TJZL-00106-ZHWZH-201811021518-D.bmp
#  2203            0   一期_690_右           028-CDFE-00009-HJ-201812260942-D.bmp
#
#                                                对侧dcm  age cup_size new_qc  \
#  0     020-ZSSYX-01921-LRLI-202302151438-双波段-R-D.dcm   69        B     合格
#  1      020-ZSSYX-0150-LYFA-202203021008-单波段-L-D.dcm   63        C     合格
#  2     020-ZSSYX-00423-ZGXI-202204131053-双波段-R-D.dcm   50        C     合格
#  3     020-ZSSYX-01772-TAMI-202210201559-双波段-L-D.dcm   31        D     合格
#  4     020-ZSSYX-00504-LYFE-202204240954-双波段-L-D.dcm   34        C     合格
#  ...                                             ...  ...      ...    ...
#  2199      0571-ZHJSH-00019-HPX-201807090946-D-R.dcm   29        C     合格
#  2200                                            NaN   47        B     合格
#  2201                                            NaN   38        B     合格
#  2202                                            NaN   44        C     合格
#  2203           028-CDFE-00009-HJ-201812260942-D.dcm   56        D     合格
#
#                                                   病灶位置     是否乳头区  可分析的dcm采集类型  \
#  0                                  ['[nan]', '[nan]']        未知            1
#  1                                  ['[nan]', '[nan]']        未知            1
#  2                         ['[nan]', '[nan]', '[nan]']        未知            1
#  3                                  ['[nan]', '[nan]']        未知            1
#  4                                  ['[nan]', '[nan]']        未知            1
#  ...                                               ...       ...          ...
#  2199                                            1点/2点      非乳头区            1
#  2200                                    NULL右乳下方右乳上象限      非乳头区            1
#  2201                                           左内侧左内下      非乳头区            1
#  2202                                       内上内侧距乳头2cm       乳头区            1
#  2203  9点距乳头2-3cm9点距乳头约2-3cm/9-10点距乳头2cm/10点距乳头3cmNULL  乳头区，非乳头区            1
#
#        ...                us_size us_bi_rads mg_location  mg_size  mg_bi_rads  \
#  0     ...     ['19.0*15.0*12.0']     ['4C']         NaN      NaN         NaN
#  1     ...           ['15.0*6.0']     ['4A']         NaN      NaN         NaN
#  2     ...           ['13.0*5.0']     ['4A']       [nan]    [nan]       ['2']
#  3     ...     ['42.0*24.0*42.0']     ['4A']         NaN      NaN         NaN
#  4     ...          ['19.0*10.0']     ['4A']         NaN      NaN         NaN
#  ...   ...                    ...        ...         ...      ...         ...
#  2199  ...  ['6.9*5.5/18.3*10.8']      ['3']         NaN      NaN         NaN
#  2200  ...           ['17*11*15']     ['4A']   ['右乳上象限']    [nan]       ['3']
#  2201  ...            ['10*14*9']     ['4C']     ['左内下']    [nan]       ['0']
#  2202  ...              ['37*20']     ['4B']         NaN      NaN         NaN
#  2203  ...      ['6*5*6/5*2/4*3']     ['4A']       [nan]    [nan]       [nan]
#
#       mri_location mri_size mri_bi_rads is_normal_dcm  \
#  0             NaN      NaN         NaN             0
#  1             NaN      NaN         NaN             1
#  2             NaN      NaN         NaN             1
#  3             NaN      NaN         NaN             0
#  4             NaN      NaN         NaN             1
#  ...           ...      ...         ...           ...
#  2199          NaN      NaN         NaN             1
#  2200          NaN      NaN         NaN             1
#  2201          NaN      NaN         NaN             1
#  2202          NaN      NaN         NaN             1
#  2203          NaN      NaN         NaN             1
#
#                         dcm_type
#  0     LittleLED=2;TwoLEDMode=0;
#  1                           NaN
#  2                           NaN
#  3     LittleLED=2;TwoLEDMode=0;
#  4                           NaN
#  ...                         ...
#  2199                        NaN
#  2200                        NaN
#  2201                        NaN
#  2202                        NaN
#  2203                        NaN
#
#  [2204 rows x 33 columns])

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
train=pd.concat([x_train,y_train],axis=1)
test=pd.concat([x_test,y_test],axis=1)

# %%
train
# Out:
#       是否为上海肿瘤数据类型       ids                                        dcm_name  \
# 735             0  4_2335_左   020-ZSSYX-01783-QIDA-202210241435-双波段-L-D.bmp
# 721             1  4_2285_左   020-ZSSYX-01751-WAYU-202210141039-双波段-L-D.bmp
# 1317            1  一期_749_左           029-CDFE-00041-ZHL-201902221045-D.bmp
# 805             0   5_538_右  0571-ZKYZL-00064-XYNA-202204011116-双波段15-R.bmp
# 1292            1  一期_987_左          0571-ZHJSH-00411-JP-201907161003-D.bmp
# ...           ...       ...                                             ...
# 1033            0  一期_490_右       0571-ZHJSH-00094-XHP-201808081031-D-R.bmp
# 1731            0  一期_240_右       029-XAJD-00058-LSHSH-201806011604-D-R.bmp
# 763             0   7_469_右         SCCDFY001-HCQI-202202212128-双波段15-R.bmp
# 835             0  5_2322_左   0571-ZKYZL-S177-YYYI-202210211422-双波段15-L.bmp
# 1653            0  一期_395_左          021-SHZL-00250-CHYH-201807201011-D.bmp
#
#                                                对侧dcm  age cup_size    new_qc  \
# 735    020-ZSSYX-01783-QIDA-202210241439-双波段-R-D.dcm   60        B        合格
# 721                                              NaN   52        C        合格
# 1317                                             NaN   29        B        合格
# 805   0571-ZKYZL-00064-XYNA-202204011109-双波段15-L.dcm   28        B  2.3 2.10
# 1292                                             NaN   36        B        合格
# ...                                              ...  ...      ...       ...
# 1033       0571-ZHJSH-00094-XHP-201808081027-D-L.dcm   45        A        合格
# 1731       029-XAJD-00058-LSHSH-201806011616-D-L.dcm   20        B      2.10
# 763          SCCDFY001-HCQI-202202212123-双波段15-L.dcm   49        D        合格
# 835    0571-ZKYZL-S177-YYYI-202210211426-双波段15-R.dcm   31        A        合格
# 1653                                             NaN   47        B      2.10
#
#                                                    病灶位置     是否乳头区  \
# 735                                             ['乳头区']       乳头区
# 721                                    ['外（左3,右9）', '']      非乳头区
# 1317            左3点/4点/6点/12点左乳12点距乳头5cm/左乳4点距乳头3cmNULL      非乳头区
# 805                                   ['腋窝肿块']['下方、外侧']      非乳头区
# 1292                                       NULL左12点NULL      非乳头区
# ...                                                 ...       ...
# 1033                                          右乳7点右乳外象限      非乳头区
# 1731                                   右6点右乳6点钟/8点钟NULL      非乳头区
# 763   ['右乳肿块', '右乳12-1点钟肿块']['9-10点钟位距乳头约1cm处1', '99...  乳头区，非乳头区
# 835             ['左乳外上']['上方、外侧']['上方、外侧', '分布点状，粗大钙化']      非乳头区
# 1653                                           左乳内上左乳外上      非乳头区
#
#       可分析的dcm采集类型  ...             us_bi_rads             mg_location  \
# 735             1  ...                 ['4C']                   [nan]
# 721             1  ...                  ['5']                   [nan]
# 1317            1  ...                  ['3']                   [nan]
# 805             1  ...                  ['3']                     NaN
# 1292            1  ...                 ['4A']                   [nan]
# ...           ...  ...                    ...                     ...
# 1033            1  ...                 ['4A']               ['右乳外象限']
# 1731            1  ...                 ['4A']                   [nan]
# 763             1  ...  ['3', '3', '3', '4B']                     NaN
# 835             1  ...                 ['4A']  ['上方、外侧', '分布点状，粗大钙化']
# 1653            1  ...                 ['4B']                ['左乳外上']
#
#          mg_size  mg_bi_rads  mri_location mri_size mri_bi_rads is_normal_dcm  \
# 735        [nan]      ['4C']           NaN      NaN         NaN             0
# 721        [nan]       ['5']         [nan]    [nan]       ['5']             0
# 1317       [nan]       [nan]           NaN      NaN         NaN             1
# 805          NaN         NaN           NaN      NaN         NaN             1
# 1292       [nan]       [nan]           NaN      NaN         NaN             1
# ...          ...         ...           ...      ...         ...           ...
# 1033       [nan]       ['3']           NaN      NaN         NaN             1
# 1731       [nan]       [nan]           NaN      NaN         NaN             1
# 763          NaN         NaN           NaN      NaN         NaN             1
# 835   [nan, nan]  ['3', '2']           NaN      NaN         NaN             0
# 1653       [nan]      ['4B']           NaN      NaN         NaN             1
#
#                        dcm_type tumor_nature
# 735   LittleLED=2;TwoLEDMode=0;            1
# 721   LittleLED=2;TwoLEDMode=0;            1
# 1317                        NaN            0
# 805                         NaN            0
# 1292                        NaN            0
# ...                         ...          ...
# 1033                        NaN            0
# 1731                        NaN            0
# 763                         NaN            0
# 835   LittleLED=2;TwoLEDMode=0;            0
# 1653                        NaN            1
#
# [1653 rows x 34 columns]

# %%
test
# Out:
#       是否为上海肿瘤数据类型        ids                                       dcm_name  \
# 1266            1   一期_952_右        0571-ZHJSH-00375-ZHJ-201907010919-D.bmp
# 200             0   4_2597_右  020-ZSSYX-01939-CJQI-202302210920-双波段-R-D.bmp
# 333             1   4_2209_右  020-ZSSYX-01696-LFQI-202210081052-双波段-R-D.bmp
# 1367            1  一期_1239_右           028-CDEF-00142-LY-201909241535-D.bmp
# 206             0   4_2617_右  020-ZSSYX-01953-ZYJI-202302270903-双波段-R-D.bmp
# ...           ...        ...                                            ...
# 1058            0   一期_458_右        0571-ZHJSH-00117-LSQ-201808240946-D.bmp
# 1727            0   一期_234_左          029-XAJD-00052-BWL-201805281033-D.bmp
# 2084            1   一期_181_右          021-SHZL-00081-LJQ-201711070922-D.bmp
# 2007            1   一期_932_左       0571-ZHJSH-00354-ZHBX-201906201014-D.bmp
# 1060            0   一期_460_右        0571-ZHJSH-00119-YJP-201808241110-D.bmp
#
#                                               对侧dcm  age cup_size     new_qc  \
# 1266                                            NaN   43        D         合格
# 200   020-ZSSYX-01939-CJQI-202302210924-双波段-L-D.dcm   19        A         合格
# 333   020-ZSSYX-01696-LFQI-202210081100-双波段-L-D.dcm   71        B         合格
# 1367                                            NaN   35        B         合格
# 206                                             NaN   24        B  2.10 2.12
# ...                                             ...  ...      ...        ...
# 1058                                            NaN   20        B        2.3
# 1727          029-XAJD-00052-BWL-201805281027-D.dcm   34        B         合格
# 2084                                            NaN   76        C         合格
# 2007       0571-ZHJSH-00354-ZHBX-201906201014-D.dcm   55        D         合格
# 1060                                            NaN   36        A       2.10
#
#                            病灶位置 是否乳头区  可分析的dcm采集类型  ... us_bi_rads  \
# 1266  右8点/右12点右乳12点/右乳5点/8点NULL  非乳头区            1  ...      ['3']
# 200          ['[nan]', '[nan]']    未知            1  ...      ['3']
# 333                ['外（左3,右9）']  非乳头区            1  ...      ['5']
# 1367        NULL9-10点钟距离乳头5.0cm  非乳头区            1  ...     ['4A']
# 206          ['[nan]', '[nan]']    未知            1  ...     ['4A']
# ...                         ...   ...          ...  ...        ...
# 1058             右乳4-5点/右11-12点  非乳头区            1  ...      ['3']
# 1727               左乳4点4点钟方向乳头旁   乳头区            1  ...     ['4A']
# 2084                       右乳外侧  非乳头区            1  ...     ['4C']
# 2007               左3点左3点左乳外上象限  非乳头区            1  ...     ['4A']
# 1060                右乳10点/右乳11点  非乳头区            1  ...      ['3']
#
#      mg_location mg_size  mg_bi_rads  mri_location mri_size mri_bi_rads  \
# 1266       [nan]   [nan]       [nan]           NaN      NaN         NaN
# 200          NaN     NaN         NaN           NaN      NaN         NaN
# 333        [nan]   [nan]       ['5']           NaN      NaN         NaN
# 1367         NaN     NaN         NaN           NaN      NaN         NaN
# 206          NaN     NaN         NaN           NaN      NaN         NaN
# ...          ...     ...         ...           ...      ...         ...
# 1058         NaN     NaN         NaN           NaN      NaN         NaN
# 1727         NaN     NaN         NaN           NaN      NaN         NaN
# 2084         NaN     NaN         NaN           NaN      NaN         NaN
# 2007  ['左乳外上象限']   [nan]       ['2']           NaN      NaN         NaN
# 1060         NaN     NaN         NaN           NaN      NaN         NaN
#
#      is_normal_dcm                   dcm_type tumor_nature
# 1266             1                        NaN            0
# 200              0  LittleLED=2;TwoLEDMode=0;            0
# 333              0  LittleLED=2;TwoLEDMode=0;            1
# 1367             1                        NaN            0
# 206              0  LittleLED=2;TwoLEDMode=0;            0
# ...            ...                        ...          ...
# 1058             1                        NaN            0
# 1727             1                        NaN            0
# 2084             1                        NaN            1
# 2007             1                        NaN            0
# 1060             1                        NaN            0
#
# [551 rows x 34 columns]

# %%
train.to_excel("../data/train.xlsx",index=False)

# %%
test.to_excel("../data/test.xlsx",index=False)
